# %% [markdown]
# # Using the ESCWCC API in Python

# %% [markdown]
# Import required packages

# %%
import requests
import json
import pandas
pandas.options.mode.chained_assignment = None

# %% [markdown]
# ## Establish API GET request URL

# %%
base_url = "http://209.97.132.245:8000/ESCWCC?"

# %% [markdown]
# Set the longitude (lon) and latitude (lat) in EPSG:3857.

# %%
lon = -141102.7542
lat = 6830259.9735

# lon = -184144
# lat = 7171860

# %% [markdown]
# Establish the site modifier options.
#
# * drainage:int
#     * 0 = None.
#     * 1 = Drainage installed.
# * brash:int
#     * 0 = None (new planting).
#     * 1 = Fresh brash (<18 months).
#     * 2 = Brash (>18 months).
# * fertiliser:int
#     * 0 = None.
#     * 1 = Fertiliser applied.
# * exposure:int
#     * 0 = None.
#     * 1 = Exposed ridge/Coastal zone.
#     * 2 = Local shelter/Less exposed/Underplanting.

# %%
drainage = 0
brash = 0
fertiliser = 0
exposure = 0

# %% [markdown]
# Establish the climate scenario/s (climate), species group filter (filter), and ESC version.
#
# * climate:int
#     * 0 = Baseline.
#     * 1 = 2050.
#     * 2 = 2080.
#     * 3 = Baseline, 2050, and 2080.
# * filter:int
#     * 0 = No filter
#     * 1 = Conifers only
#     * 2 = Broadleaves only
#     * 3 = Natives only
#     * 4 = Non-natives only
# * escVersion:float
#     * 4.33 = 4.33

# %%
climate = 3
filter = 0
escVersion = 4.33

# %% [markdown]
# Establish the Woodland Carbon Code (WCC) version (wccVersion), the planting spacing (wccSpacing), management regime (thinning or no thinning) (wccManagement), period (wccPeriod), area of the site to be established (wccEstArea) in hectares (ha), the length of roads to be constructed (wccRoadLength) in km, and the area, if any, of arable land with mineral soil to be planted (wccSoilArea) in ha.
# * wccVersion:float
#     * 2.4 = v2.4 (March 2021)
# * wccSpacing:list
#     * 0 = 'all', eqiuvalent to {0: [1.2, 2.5, 3.0, 1.4, 1.7, 1.8, 1.5, 2.0]}
# * wccManagement:list
#     * 0 = 'all', eqiuvalent to {0: ["NO_thin", "Thinned"]}
# * wccPeriod:list
#     * 0 = 'all', eqiuvalent to {0: ["0", "0-5", "5-10", "10-15", "15-20", "20-25", "25-30", "30-35", "35-40", "40-45", "45-50",
#                                     "50-55", "55-60", "60-65", "65-70", "70-75", "75-80", "80-85", "85-90", "90-95", "95-100",
#                                     "100-105", "105-110", "110-115", "115-120", "120-125", "125-130", "130-135", "135-140",
#                                     "140-145", "145-150", "150-155", "155-160", "160-165", "165-170", "170-175", "175-180",
#                                     "180-185", "185-190", "190-195", "195-200"]}
# * wccEstArea:float
#     * 0 by default, any positive number.
# * wccRoadLength:float
#     * 0 by default, any positive number.
# * wccSoilArea:float
#     * 0 by default, any positive number.

# %%
wccVersion = 0 #2.4
wccSpacing = 0
wccManagement = 0
wccPeriod = 0
wccEstArea = 12
wccRoadLength = 1
wccSoilArea = 2

# %% [markdown]
# Establish the manual Soil Moisture Regime (SMR) and Soil Nutrient Regime (SNR) modifier values.
# Enter None, or omit from the request dictionary (`req_dict`) below if you do not wish to manually alter the values.
#
# * smr:float, any number between 0 and 8. Indicative categorical values are as follows:
#     * 1 = Very Wet
#     * 2 = Wet
#     * 3 = Moist
#     * 4 = Moist
#     * 5 = Fresh
#     * 6 = Slightly Dry
#     * 7 = Moderately Dry
#     * 8 = Very Dry
# * snr:float, any number between 0 and 6. Indicative categorical values are as follows:
#     * 0 = Very Poor (VP1)
#     * 0.5 = Very Poor (VP2)
#     * 1 = Very Poor (VP3)
#     * 1.5 = Very Poor - Poor
#     * 2 = Poor
#     * 3 = Medium
#     * 4 = Rich
#     * 5 = Very Rich
#     * 6 = Carbonate

# %%
smr = None
snr = None

# %% [markdown]
# Compose the request dictionary. Optionally, you can accept the default values for all parameters apart from lon and lat by emitting the parameters from the request dictionary (as shown in the commented out code below).

# %%
# req_dict = {"lon": lon, "lat": lat}

req_dict = {"lon": lon, "lat": lat, "drainage": drainage, "brash": brash, "fertiliser": fertiliser, "exposure": exposure, 
            "climate": climate, "filter": filter, "escVersion": escVersion, "wccVersion": wccVersion, "smr": smr, "snr": snr,
            "wccSpacing": wccSpacing, "wccManagement": wccManagement, "wccPeriod": wccPeriod,
            "wccEstArea": wccEstArea, "wccRoadLength": wccRoadLength, "wccSoilArea": wccSoilArea}

req_dict
# Out:
# {'lon': -141102.7542,
#  'lat': 6830259.9735,
#  'drainage': 0,
#  'brash': 0,
#  'fertiliser': 0,
#  'exposure': 0,
#  'climate': 3,
#  'filter': 0,
#  'escVersion': 4.33,
#  'wccVersion': 0,
#  'smr': None,
#  'snr': None,
#  'wccSpacing': 0,
#  'wccManagement': 0,
#  'wccPeriod': 0,
#  'wccEstArea': 12,
#  'wccRoadLength': 1,
#  'wccSoilArea': 2}

# %% [markdown]
# ## Make the API call

# %% [markdown]
# Call the ESC API using the base url and request dictionary

# %%
ESCresponse = requests.get(url = base_url, params = req_dict)
ESCresponse.json
# Out:
# <bound method Response.json of <Response [200]>>

# %% [markdown]
# Establish a function to deserialize the json response into a nested dictionary.

# %%
def deserializeESCTreeResults(nestedJson:str) -> dict:
    
    loadedJson = json.loads(nestedJson)

    for k,v in loadedJson.items():
        loadedJson[k] = json.loads(v)
        for t,c in loadedJson[k].items():
            loadedJson[k][t] = pandas.DataFrame.from_dict(data = json.loads(c))
            
    return loadedJson

# %% [markdown]
# Call the `deserializeResults` function on the ESC API output.

# %%
ESCresponse_dict = deserializeESCTreeResults(ESCresponse.json())
ESCresponse_dict.keys()
# Out:
# dict_keys(['Baseline', '2050', '2080'])

# %% [markdown]
# ## Explore Results

# %% [markdown]
# The object produced (`ESCresponse_dict`) is a nested dictionary with the following structure:
#
# ```
# ESCresponse_dict (dict)
# ├── Metadata (dict)
# │   ├── ESCMetadata (DataFrame)
# │   ├── WCCMetadata (DataFrame)
# ├── Baseline (dict)
# │   ├── ESCDoseVals (DataFrame)
# │   ├── ESCResponseVals (DataFrame)
# │   ├── ESCSuitMetrics (DataFrame)
# │   ├── WCCTreeValues (DataFrame)
# │   ├── WCCSoilLoss (DataFrame)
# │   ├── WCCSoilSeq (DataFrame)
# │   ├── WCCEstablishment (DataFrame)
# ├── 2050 (dict)
# │   ├── ESCDoseVals (DataFrame)
# │   ├── ESCResponseVals (DataFrame)
# │   ├── ESCSuitMetrics (DataFrame)
# │   ├── WCCTreeValues (DataFrame)
# │   ├── WCCSoilLoss (DataFrame)
# │   ├── WCCSoilSeq (DataFrame)
# │   ├── WCCEstablishment (DataFrame)
# ├── 2080 (dict)
# │   ├── ESCDoseVals (DataFrame)
# │   ├── ESCResponseVals (DataFrame)
# │   ├── ESCSuitMetrics (DataFrame)
# │   ├── WCCTreeValues (DataFrame)
# │   ├── WCCSoilLoss (DataFrame)
# │   ├── WCCSoilSeq (DataFrame)
# │   ├── WCCEstablishment (DataFrame)
# ```

# %%
ESCresponse_dict.get("Baseline").keys()
# Out:
# dict_keys(['ESCDoseVals', 'ESCResponseVals', 'ESCSuitMetrics', 'WCCTreeValues', 'WCCEstablishment', 'WCCSoilLoss', 'WCCSoilSeq'])

# %% [markdown]
# Inspect the metadata for the ESC and WCC values.

# %%
#ESCresponse_dict.get("Metadata").get("ESCMetadata")

# %%
#ESCresponse_dict.get("Metadata").get("WCCMetadata")

# %% [markdown]
# Access the ESC & WCC data frames from the API response for a given climate scenario using the following code.

# %% [markdown]
# The `ESCDoseVals` data frame contains the environmental dose variables obtained from the modelled data and/or manually entered, which are then modified by the aforementioned API query parameters `drainage`, `brash`, `fertiliser`, and `exposure`.
# For more information on the underlying method see the [Forest Research Bulletin 124](https://www.forestresearch.gov.uk/publications/archive-an-ecological-site-classification-for-forestry-in-great-britain/) and the [Forest Research Technical Paper 20](https://www.forestresearch.gov.uk/publications/archive-an-ecological-site-classification-for-forestry-in-great-britain-with-special-reference-to-grampian-scotland/).
# Column definitions:
# * SMR - soil moisture regime
# * SNR - soil nutrient regime
# * AT - accumulated temperature
# * CT - continentality
# * DAMS - direct aspect method of scoring
# * MD - moisture deficit
# * Item - The stage of modification of the environmental dose variable values.

# %%
baseline_ESCDoseVals = ESCresponse_dict.get("Baseline").get("ESCDoseVals")
baseline_ESCDoseVals
# Out:
#    SMR  SNR           AT        CT       DAMS          MD  \
# 0  3.0  3.0  1422.723145  9.027328  12.510952  145.714996
# 1  NaN  NaN          NaN       NaN        NaN         NaN
# 2  3.0  3.0  1422.723145  9.027328  12.510952  145.714996
# 3  0.0  0.0     0.000000  0.000000   0.000000    0.000000
# 4  0.0  0.0     0.000000  0.000000   0.000000    0.000000
# 5  0.0  0.0     0.000000  0.000000   0.000000    0.000000
# 6  0.0  0.0     0.000000  0.000000   0.000000    0.000000
# 7  3.0  3.0  1422.723145  9.027328  12.510952  145.714996
#
#                     Item
# 0          Values - Base
# 1        Values - Manual
# 2        Values - PreMod
# 3    Modifier - Drainage
# 4       Modifier - Brash
# 5  Modifier - Fertiliser
# 6    Modifier - Exposure
# 7         Values - Final

# %% [markdown]
# The `ESCResponseVals` data frame contains data on the response of each tree species to each environmental dose metric.
# Column definitions:
# * speciesCode - The Forest Research species code for the species.
# * metric - The environmental dose variable (see above).
# * response - The response of the tree species to the environmental dose variable. A unitless value between 0 and 1.

# %%
baseline_ESCResponseVals = ESCresponse_dict.get("Baseline").get("ESCResponseVals")
baseline_ESCResponseVals.head()
# Out:
#   speciesCode metric  response
# 0          AH     AT  1.000000
# 1          AH     CT  1.000000
# 2          AH   DAMS  0.944794
# 3          AH     MD  1.000000
# 4          AH    SMR  0.755714

# %% [markdown]
# The `ESCSuitMetrics` data frame contains a range of summary data relating to the suitability of each tree species based on the `ESCResponseVals` data.
# Column definitions:
# * speciesCode - The Forest Research species code for the species.
# * speciesScientific - The scientific name of the species.
# * speciesName - The common name of the species.
# * maxYC - The maximum yield class of that species
# * threat - Any major threats to that tree species which should be taken into account when considering planting that species.
# * limFactorInclAT - The limiting factor (metric with the lowest response) including AT.
# * limFactorInclATResponse - The response value for limiting factor (metric with the lowest response) including AT.
# * limFactorExclAT - The limiting factor (metric with the lowest response) excluding AT.
# * limFactorExclATResponse - The response value for limiting factor (metric with the lowest response) excluding AT.
# * TimberSuitability - The suitability of that tree species for planting as a timber crop.
# * EcologicalSuitability - The suitability of that tree species for planting.
# * estimatedYC - The estimated yield class.

# %%
baseline_ESCSuitMetrics = ESCresponse_dict.get("Baseline").get("ESCSuitMetrics")
# print(baseline_ESCSuitMetrics.to_string())
baseline_ESCSuitMetrics_nozero = baseline_ESCSuitMetrics[baseline_ESCSuitMetrics["estimatedYC"] != 0].reset_index(drop = True)
print(baseline_ESCSuitMetrics_nozero.speciesScientific.to_string())
# Out:
# 0             Fraxinus excelsior
# 1                Populus tremula
# 2                Fagus sylvatica
# 3                  Populus nigra
# 4                Alnus glutinosa
# 5                    Pinus nigra
# 6              Eucalyptus gunnii
# 7                  Larix decidua
# 8              Eucalyptus nitens
# 9                     Abies alba
# 10                  Alnus incana
# 11               Carpinus betula
# 12               Larix euolepsis
# 13               Ilex aquifolium
# 14              Picea sitchensis
# 15          Cryptomeria japonica
# 16               Larix kaempferi
# 17                 Juglans regia
# 18      Chamaecyparis lawsoniana
# 19    Cupressocyparis x leyandii
# 20                Pinus contorta
# 21                Pinus pinaster
# 22                   Pinus peuce
# 23            Abies nordmanianna
# 24              Acer platanoides
# 25                   Picea abies
# 26                 Picea omorika
# 27              Picea orientalis
# 28              Betula pubescens
# 29                 Quercus robur
# 30                Abies amabilis
# 31                   Alnus rubra
# 32                 Thuja plicata
# 33                 Quercus rubra
# 34            Nothofagus obliqua
# 35              Sorbus aucuparia
# 36          Sequoia sempervirens
# 37                Betula pendula
# 38                 Tilia cordata
# 39               Quercus petraea
# 40              Pinus sylvestris
# 41                    Salix spp.
# 42        Eucalyptus glaucescens
# 43              Picea sitchensis
# 44           Acer pseudoplatanus
# 45                  Prunus avium
# 46                  Ulmus glabra
# 47             Tsuga heterophyla
# 48             Sorbus torminalis
# 49                    Salix alba

# %% [markdown]
# The `WCCTreeValues` data frame contains data from the woodland carbon code biomass carbon lookup tables (BCLT) and clearfell max sequence values for the yield class nearest to the ESC estimated yield class.
# Column definitions:
# * speciesCode - The Forest Research species code for the species.
# * wccCode - The WCC species code mapped to the ESC species, from which the WCC data is retrieved.
# * speciesScientific - The scientific name of the species.
# * speciesName - The common name of the species.
# * estimatedYC - The estimated yield class.
# * YC - The yield class associated with the biomass carbon lookup tables (BCLT) and clearfell max sequence values WCC data. Retrieved from column D in the BCLT tables.
# * spacing - The planting spacing. Retrieved from column C in the BCLT tables.
# * management - The management regime for the planted area, thinned or un-thinned. Retrieved from column E in the BCLT tables.
# * period - The period of years associated with the wcc data. Retrieved from column F in the BCLT tables.
# * standingCarbonYr - The carbon contained within the above-ground biomass of the trees planted on site. Retrieved from column G in the BCLT tables. Units of tCO2e/ha/yr.
# * debrisCarbonYr - The carbon contained within the debris on site. Retrieved from column H in the BCLT tables. Units of tCO2e/ha/yr.
# * totalCarbonYr - The total carbon contained on site, equal to the sum of standingCarbonYr and debrisCarbonYr. Retrieved from column I in the BCLT tables. Units of tCO2e/ha/yr.
# * cumCarbon5Yr - The cumulative carbon sequestered on site over the period stipulated in the period column. Retrieved from column J in the BCLT tables. Units of tCO2e/ha/period.
# * cumBiomassCarbon - The cumulative carbon sequestered on site over up until the period stipulated in the period column. Retrieved from column K in the BCLT tables. Units of tCO2e/ha.
# * cumEmissionsMgmt - The cumulative emissions from ongiong management on site. Retrieved from column L in the BCLT tables. Units of tCO2e/ha.
# * cumTotalCarbon - The total cumulative emissions on site. Retrieved from column M in the BCLT tables. Units of tCO2e/ha.
# * remCarbonYr - The quantity of carbon removed from the site yearly. Retrieved from column N in the BCLT tables. Units of tCO2e/ha/yr.
# * periodEnd - The rotation length stipulated in columns F to AK of the "Clearfell_Max_Seq_Values" sheet of the excel tool. Mapped to the last year of the period present in the period column.
# * clearfellCapCarbon - The Clearfell Cap Value associated with the periodEnd, wccCode, spacing, YC, and management. Units of tCO2e.

# %%
baseline_WCCTreeValues = ESCresponse_dict.get("Baseline").get("WCCTreeValues")
# baseline_WCCTreeValues.head()
print(baseline_WCCTreeValues.to_string())
# Out:
#      speciesCode wccCode              speciesScientific                    speciesName  estimatedYC    YC  spacing management   period  standingCarbonYr  debrisCarbonYr  totalCarbonYr  cumCarbon5Yr  cumBiomassCarbon  cumEmissionsMgmt  cumTotalCarbon  remCarbonYr  periodEnd  clearfellCapCarbon
# 0             AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin      0-5              4.07            0.52           4.59          23.0              23.0              0.00            23.0         0.00        5.0                 6.5
# 1             AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin     5-10             12.42            0.65          13.06          65.3              88.3              0.00            88.3         0.00       10.0                13.0
# 2             AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin    10-15             29.50            1.34          30.84         154.2             242.5              0.00           242.5         0.00       15.0                64.0
# 3             AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin    15-20             26.84            0.82          27.66         138.3             380.8              0.00           380.8         0.00       20.0               115.0
# 4             AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin    20-25             19.91            3.53          23.44         117.2             498.0              0.00           498.0         0.00       25.0               175.0
# 5             AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin    25-30             14.58           12.91          27.49         137.5             635.5              0.00           635.5         0.00       30.0               235.0
# 6             AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin    30-35             12.45            5.16          17.61          88.1             723.5              0.00           723.5         0.00       35.0               292.0
# 7             AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin    35-40             12.25            0.64          12.89          64.5             788.0              0.00           788.0         0.00       40.0               349.0
# 8             AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin    40-45             10.96           -0.88          10.08          50.4             838.4              0.00           838.4         0.00       45.0               394.5
# 9             AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin    45-50              9.69           -1.62           8.07          40.4             878.7              0.00           878.7         0.00       50.0               440.0
# 10            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin    50-55              8.56           -1.81           6.74          33.7             912.5              0.00           912.5         0.00       55.0               477.0
# 11            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin    55-60              7.46           -1.44           6.03          30.1             942.6              0.00           942.6         0.00       60.0               514.0
# 12            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin    60-65              6.28           -1.66           4.62          23.1             965.7              0.00           965.7         0.00       65.0               544.5
# 13            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin    65-70              5.60           -1.49           4.11          20.5             986.2              0.00           986.2         0.00       70.0               575.0
# 14            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin    70-75              5.02           -0.81           4.21          21.0            1007.2              0.00          1007.2         0.00       75.0               600.5
# 15            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin    75-80              4.49           -1.47           3.02          15.1            1022.3              0.00          1022.3         0.00       80.0               626.0
# 16            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin    80-85              3.95           -0.72           3.24          16.2            1038.5              0.00          1038.5         0.00       85.0               647.5
# 17            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin    85-90              3.52           -0.59           2.93          14.6            1053.1              0.00          1053.1         0.00       90.0               669.0
# 18            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin    90-95              3.07           -0.57           2.50          12.5            1065.7              0.00          1065.7         0.00       95.0               687.5
# 19            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin   95-100              2.77           -0.53           2.23          11.2            1076.8              0.00          1076.8         0.00      100.0               706.0
# 20            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin  100-105              2.51           -0.32           2.19          11.0            1087.8              0.00          1087.8         0.00      105.0               722.5
# 21            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin  105-110              2.23           -0.30           1.93           9.7            1097.4              0.00          1097.4         0.00      110.0               739.0
# 22            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin  110-115              1.97           -0.46           1.51           7.5            1105.0              0.00          1105.0         0.00      115.0               753.5
# 23            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin  115-120              1.75           -0.45           1.31           6.5            1111.5              0.00          1111.5         0.00      120.0               768.0
# 24            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin  120-125              1.55           -0.35           1.20           6.0            1117.5              0.00          1117.5         0.00      125.0               780.5
# 25            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin  125-130              1.32           -0.33           0.99           5.0            1122.5              0.00          1122.5         0.00      130.0               793.0
# 26            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin  130-135              1.18           -0.23           0.95           4.8            1127.2              0.00          1127.2         0.00      135.0               804.5
# 27            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin  135-140              1.04           -0.16           0.88           4.4            1131.6              0.00          1131.6         0.00      140.0               816.0
# 28            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin  140-145              0.90           -0.18           0.72           3.6            1135.2              0.00          1135.2         0.00      145.0               826.0
# 29            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin  145-150              0.80           -0.15           0.65           3.3            1138.5              0.00          1138.5         0.00      150.0               836.0
# 30            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin  150-155              0.70           -0.18           0.52           2.6            1141.1              0.00          1141.1         0.00        NaN                 NaN
# 31            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin  155-160              0.61           -0.13           0.48           2.4            1143.5              0.00          1143.5         0.00        NaN                 NaN
# 32            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin  160-165              0.58           -0.11           0.47           2.4            1145.8              0.00          1145.8         0.00        NaN                 NaN
# 33            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin  165-170              0.53           -0.09           0.44           2.2            1148.0              0.00          1148.0         0.00        NaN                 NaN
# 34            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin  170-175              0.49           -0.08           0.41           2.0            1150.0              0.00          1150.0         0.00      175.0               872.5
# 35            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin  175-180              0.40           -0.07           0.33           1.7            1151.7              0.00          1151.7         0.00        NaN                 NaN
# 36            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin  180-185              0.31           -0.06           0.24           1.2            1152.9              0.00          1152.9         0.00        NaN                 NaN
# 37            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin  185-190              0.31           -0.06           0.26           1.3            1154.2              0.00          1154.2         0.00        NaN                 NaN
# 38            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin  190-195              0.26           -0.05           0.21           1.0            1155.3              0.00          1155.3         0.00        NaN                 NaN
# 39            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    NO_thin  195-200              0.22           -0.04           0.18           0.9            1156.2              0.00          1156.2         0.00      200.0               909.0
# 40            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned      0-5               NaN             NaN            NaN           NaN               NaN               NaN            23.0          NaN        5.0                 6.5
# 41            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned     5-10               NaN             NaN            NaN           NaN               NaN               NaN            88.3          NaN       10.0                13.0
# 42            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned    10-15               NaN             NaN            NaN           NaN               NaN               NaN           233.9          NaN       15.0                51.0
# 43            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned    15-20               NaN             NaN            NaN           NaN               NaN               NaN           290.0          NaN       20.0                89.0
# 44            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned    20-25               NaN             NaN            NaN           NaN               NaN               NaN           347.5          NaN       25.0               133.0
# 45            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned    25-30               NaN             NaN            NaN           NaN               NaN               NaN           423.3          NaN       30.0               177.0
# 46            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned    30-35               NaN             NaN            NaN           NaN               NaN               NaN           477.8          NaN       35.0               215.5
# 47            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned    35-40               NaN             NaN            NaN           NaN               NaN               NaN           528.9          NaN       40.0               254.0
# 48            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned    40-45               NaN             NaN            NaN           NaN               NaN               NaN           565.2          NaN       45.0               282.0
# 49            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned    45-50               NaN             NaN            NaN           NaN               NaN               NaN           581.3          NaN       50.0               310.0
# 50            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned    50-55               NaN             NaN            NaN           NaN               NaN               NaN           600.0          NaN       55.0               331.5
# 51            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned    55-60               NaN             NaN            NaN           NaN               NaN               NaN           606.9          NaN       60.0               353.0
# 52            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned    60-65               NaN             NaN            NaN           NaN               NaN               NaN           615.1          NaN       65.0               369.5
# 53            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned    65-70               NaN             NaN            NaN           NaN               NaN               NaN           621.5          NaN       70.0               386.0
# 54            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned    70-75               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN       75.0               399.0
# 55            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned    75-80               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN       80.0               412.0
# 56            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned    80-85               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN       85.0               423.0
# 57            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned    85-90               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN       90.0               434.0
# 58            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned    90-95               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN       95.0               443.0
# 59            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned   95-100               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN      100.0               452.0
# 60            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned  100-105               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN      105.0               459.5
# 61            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned  105-110               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN      110.0               467.0
# 62            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned  110-115               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN      115.0               473.5
# 63            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned  115-120               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN      120.0               480.0
# 64            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned  120-125               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN      125.0               485.5
# 65            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned  125-130               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN      130.0               491.0
# 66            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned  130-135               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN      135.0               495.5
# 67            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned  135-140               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN      140.0               500.0
# 68            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned  140-145               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN      145.0               504.0
# 69            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned  145-150               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN      150.0               508.0
# 70            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned  150-155               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN        NaN                 NaN
# 71            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned  155-160               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN        NaN                 NaN
# 72            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned  160-165               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN        NaN                 NaN
# 73            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned  165-170               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN        NaN                 NaN
# 74            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned  170-175               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN      175.0               522.0
# 75            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned  175-180               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN        NaN                 NaN
# 76            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned  180-185               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN        NaN                 NaN
# 77            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned  185-190               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN        NaN                 NaN
# 78            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned  190-195               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN        NaN                 NaN
# 79            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      1.5    Thinned  195-200               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN      200.0               536.0
# 80            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin      0-5              2.12            0.27           2.39          11.9              11.9              0.00            11.9         0.00        5.0                 0.5
# 81            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin     5-10              9.10            0.52           9.62          48.1              60.0              0.00            60.0         0.00       10.0                 1.0
# 82            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin    10-15             27.42            1.31          28.73         143.6             203.7              0.00           203.7         0.00       15.0                48.5
# 83            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin    15-20             34.20            1.22          35.42         177.1             380.8              0.00           380.8         0.00       20.0                96.0
# 84            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin    20-25             19.91            3.53          23.44         117.2             498.0              0.00           498.0         0.00       25.0               159.0
# 85            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin    25-30             14.58           12.91          27.49         137.5             635.5              0.00           635.5         0.00       30.0               222.0
# 86            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin    30-35             12.45            5.16          17.61          88.1             723.5              0.00           723.5         0.00       35.0               280.5
# 87            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin    35-40             12.25            0.64          12.89          64.5             788.0              0.00           788.0         0.00       40.0               339.0
# 88            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin    40-45             10.96           -0.88          10.08          50.4             838.4              0.00           838.4         0.00       45.0               385.5
# 89            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin    45-50              9.69           -1.62           8.07          40.4             878.7              0.00           878.7         0.00       50.0               432.0
# 90            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin    50-55              8.56           -1.81           6.74          33.7             912.5              0.00           912.5         0.00       55.0               469.5
# 91            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin    55-60              7.46           -1.44           6.03          30.1             942.6              0.00           942.6         0.00       60.0               507.0
# 92            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin    60-65              6.28           -1.66           4.62          23.1             965.7              0.00           965.7         0.00       65.0               538.0
# 93            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin    65-70              5.60           -1.49           4.11          20.5             986.2              0.00           986.2         0.00       70.0               569.0
# 94            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin    70-75              5.02           -0.81           4.21          21.0            1007.2              0.00          1007.2         0.00       75.0               595.0
# 95            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin    75-80              4.49           -1.47           3.02          15.1            1022.3              0.00          1022.3         0.00       80.0               621.0
# 96            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin    80-85              3.95           -0.72           3.24          16.2            1038.5              0.00          1038.5         0.00       85.0               642.5
# 97            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin    85-90              3.52           -0.59           2.93          14.6            1053.1              0.00          1053.1         0.00       90.0               664.0
# 98            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin    90-95              3.07           -0.57           2.50          12.5            1065.7              0.00          1065.7         0.00       95.0               683.0
# 99            AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin   95-100              2.77           -0.53           2.23          11.2            1076.8              0.00          1076.8         0.00      100.0               702.0
# 100           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin  100-105              2.51           -0.32           2.19          11.0            1087.8              0.00          1087.8         0.00      105.0               718.5
# 101           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin  105-110              2.23           -0.30           1.93           9.7            1097.4              0.00          1097.4         0.00      110.0               735.0
# 102           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin  110-115              1.97           -0.46           1.51           7.5            1105.0              0.00          1105.0         0.00      115.0               749.5
# 103           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin  115-120              1.75           -0.45           1.31           6.5            1111.5              0.00          1111.5         0.00      120.0               764.0
# 104           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin  120-125              1.55           -0.35           1.20           6.0            1117.5              0.00          1117.5         0.00      125.0               777.0
# 105           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin  125-130              1.32           -0.33           0.99           5.0            1122.5              0.00          1122.5         0.00      130.0               790.0
# 106           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin  130-135              1.18           -0.23           0.95           4.8            1127.2              0.00          1127.2         0.00      135.0               801.5
# 107           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin  135-140              1.04           -0.16           0.88           4.4            1131.6              0.00          1131.6         0.00      140.0               813.0
# 108           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin  140-145              0.90           -0.18           0.72           3.6            1135.2              0.00          1135.2         0.00      145.0               823.0
# 109           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin  145-150              0.80           -0.15           0.65           3.3            1138.5              0.00          1138.5         0.00      150.0               833.0
# 110           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin  150-155              0.70           -0.18           0.52           2.6            1141.1              0.00          1141.1         0.00        NaN                 NaN
# 111           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin  155-160              0.61           -0.13           0.48           2.4            1143.5              0.00          1143.5         0.00        NaN                 NaN
# 112           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin  160-165              0.58           -0.11           0.47           2.4            1145.8              0.00          1145.8         0.00        NaN                 NaN
# 113           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin  165-170              0.53           -0.09           0.44           2.2            1148.0              0.00          1148.0         0.00        NaN                 NaN
# 114           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin  170-175              0.49           -0.08           0.41           2.0            1150.0              0.00          1150.0         0.00      175.0               870.0
# 115           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin  175-180              0.40           -0.07           0.33           1.7            1151.7              0.00          1151.7         0.00        NaN                 NaN
# 116           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin  180-185              0.31           -0.06           0.24           1.2            1152.9              0.00          1152.9         0.00        NaN                 NaN
# 117           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin  185-190              0.31           -0.06           0.26           1.3            1154.2              0.00          1154.2         0.00        NaN                 NaN
# 118           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin  190-195              0.26           -0.05           0.21           1.0            1155.3              0.00          1155.3         0.00        NaN                 NaN
# 119           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    NO_thin  195-200              0.22           -0.04           0.18           0.9            1156.2              0.00          1156.2         0.00      200.0               907.0
# 120           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned      0-5               NaN             NaN            NaN           NaN               NaN               NaN            11.9          NaN        5.0                 0.5
# 121           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned     5-10               NaN             NaN            NaN           NaN               NaN               NaN            60.0          NaN       10.0                 1.0
# 122           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned    10-15               NaN             NaN            NaN           NaN               NaN               NaN           196.5          NaN       15.0                37.5
# 123           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned    15-20               NaN             NaN            NaN           NaN               NaN               NaN           290.0          NaN       20.0                74.0
# 124           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned    20-25               NaN             NaN            NaN           NaN               NaN               NaN           347.5          NaN       25.0               121.0
# 125           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned    25-30               NaN             NaN            NaN           NaN               NaN               NaN           423.3          NaN       30.0               168.0
# 126           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned    30-35               NaN             NaN            NaN           NaN               NaN               NaN           477.8          NaN       35.0               207.5
# 127           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned    35-40               NaN             NaN            NaN           NaN               NaN               NaN           528.9          NaN       40.0               247.0
# 128           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned    40-45               NaN             NaN            NaN           NaN               NaN               NaN           565.2          NaN       45.0               276.0
# 129           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned    45-50               NaN             NaN            NaN           NaN               NaN               NaN           581.3          NaN       50.0               305.0
# 130           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned    50-55               NaN             NaN            NaN           NaN               NaN               NaN           600.0          NaN       55.0               327.0
# 131           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned    55-60               NaN             NaN            NaN           NaN               NaN               NaN           606.9          NaN       60.0               349.0
# 132           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned    60-65               NaN             NaN            NaN           NaN               NaN               NaN           615.1          NaN       65.0               366.0
# 133           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned    65-70               NaN             NaN            NaN           NaN               NaN               NaN           621.5          NaN       70.0               383.0
# 134           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned    70-75               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN       75.0               396.5
# 135           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned    75-80               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN       80.0               410.0
# 136           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned    80-85               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN       85.0               421.0
# 137           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned    85-90               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN       90.0               432.0
# 138           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned    90-95               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN       95.0               441.0
# 139           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned   95-100               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN      100.0               450.0
# 140           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned  100-105               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN      105.0               457.5
# 141           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned  105-110               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN      110.0               465.0
# 142           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned  110-115               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN      115.0               471.5
# 143           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned  115-120               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN      120.0               478.0
# 144           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned  120-125               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN      125.0               484.0
# 145           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned  125-130               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN      130.0               490.0
# 146           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned  130-135               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN      135.0               494.0
# 147           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned  135-140               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN      140.0               498.0
# 148           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned  140-145               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN      145.0               502.5
# 149           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned  145-150               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN      150.0               507.0
# 150           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned  150-155               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN        NaN                 NaN
# 151           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned  155-160               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN        NaN                 NaN
# 152           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned  160-165               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN        NaN                 NaN
# 153           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned  165-170               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN        NaN                 NaN
# 154           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned  170-175               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN      175.0               521.5
# 155           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned  175-180               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN        NaN                 NaN
# 156           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned  180-185               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN        NaN                 NaN
# 157           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned  185-190               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN        NaN                 NaN
# 158           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned  190-195               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN        NaN                 NaN
# 159           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      2.5    Thinned  195-200               NaN             NaN            NaN           NaN               NaN               NaN           623.2          NaN      200.0               536.0
# 160           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      3.0    NO_thin      0-5              1.78            0.23           2.01          10.1              10.1              0.00            10.1         0.00        5.0                 0.0
# 161           AH     SAB             Fraxinus excelsior                            Ash     9.068572  10.0      3.0    NO_thin     5-10              8.52            0.50           9.03          45.1              55.2              0.00            55.2         0.00       10.0                 0.0
# ...
# 4346         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   2.0      2.0    NO_thin  130-135               NaN             NaN            NaN           NaN               NaN               NaN           277.4          NaN        NaN                 NaN
# 4347         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   2.0      2.0    NO_thin  135-140               NaN             NaN            NaN           NaN               NaN               NaN           279.7          NaN        NaN                 NaN
# 4348         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   2.0      2.0    NO_thin  140-145               NaN             NaN            NaN           NaN               NaN               NaN           281.2          NaN        NaN                 NaN
# 4349         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   2.0      2.0    NO_thin  145-150               NaN             NaN            NaN           NaN               NaN               NaN           282.4          NaN        NaN                 NaN
# 4350         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   2.0      2.0    NO_thin  150-155               NaN             NaN            NaN           NaN               NaN               NaN           283.5          NaN        NaN                 NaN
# 4351         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   2.0      2.0    NO_thin  155-160               NaN             NaN            NaN           NaN               NaN               NaN           284.6          NaN        NaN                 NaN
# 4352         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   2.0      2.0    NO_thin  160-165               NaN             NaN            NaN           NaN               NaN               NaN           285.4          NaN        NaN                 NaN
# 4353         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   2.0      2.0    NO_thin  165-170               NaN             NaN            NaN           NaN               NaN               NaN           286.1          NaN        NaN                 NaN
# 4354         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   2.0      2.0    NO_thin  170-175               NaN             NaN            NaN           NaN               NaN               NaN           286.6          NaN        NaN                 NaN
# 4355         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   2.0      2.0    NO_thin  175-180               NaN             NaN            NaN           NaN               NaN               NaN           288.0          NaN        NaN                 NaN
# 4356         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   2.0      2.0    NO_thin  180-185               NaN             NaN            NaN           NaN               NaN               NaN           288.2          NaN        NaN                 NaN
# 4357         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   2.0      2.0    NO_thin  185-190               NaN             NaN            NaN           NaN               NaN               NaN           288.7          NaN        NaN                 NaN
# 4358         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   2.0      2.0    NO_thin  190-195               NaN             NaN            NaN           NaN               NaN               NaN           288.5          NaN        NaN                 NaN
# 4359         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   2.0      2.0    NO_thin  195-200               NaN             NaN            NaN           NaN               NaN               NaN           288.4          NaN        NaN                 NaN
# 4360         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin      0-5               NaN             NaN            NaN           NaN               NaN               NaN             0.0          NaN        NaN                 NaN
# 4361         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin     5-10              0.00            0.07           0.07           0.4               0.4              0.00             0.4          NaN        NaN                 NaN
# 4362         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin    10-15              0.01            0.09           0.10           0.5               0.9              0.00             0.9          NaN        NaN                 NaN
# 4363         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin    15-20              0.04            0.09           0.13           0.6               1.5              0.00             1.5          NaN        NaN                 NaN
# 4364         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin    20-25              0.12            0.09           0.21           1.1               2.6              0.00             2.6          NaN        NaN                 NaN
# 4365         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin    25-30              0.37            0.09           0.46           2.3               4.9              0.00             4.9          NaN        NaN                 NaN
# 4366         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin    30-35              1.14            0.09           1.23           6.2              11.0              0.00            11.0          NaN        NaN                 NaN
# 4367         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin    35-40              3.49            0.09           3.58          17.9              28.9              0.00            28.9          NaN        NaN                 NaN
# 4368         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin    40-45             10.65            0.09          10.74          53.7              82.6              0.00            82.6          NaN        NaN                 NaN
# 4369         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin    45-50             17.45            0.58          18.03          90.1             172.8              0.00           172.8          NaN        NaN                 NaN
# 4370         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin    50-55              8.22            0.33           8.55          42.7             215.5              0.00           215.5          NaN        NaN                 NaN
# 4371         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin    55-60              8.11            0.19           8.30          41.5             257.0              0.00           257.0          NaN        NaN                 NaN
# 4372         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin    60-65              7.77            0.21           7.98          39.9             296.9              0.00           296.9          NaN        NaN                 NaN
# 4373         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin    65-70              7.65            0.20           7.85          39.3             336.2              0.00           336.2          NaN        NaN                 NaN
# 4374         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin    70-75              7.11            0.18           7.29          36.5             372.6              0.00           372.6          NaN        NaN                 NaN
# 4375         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin    75-80              6.36            0.16           6.52          32.6             405.2              0.00           405.2          NaN        NaN                 NaN
# 4376         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin    80-85              4.91            1.28           6.19          30.9             436.2              0.00           436.2          NaN        NaN                 NaN
# 4377         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin    85-90              3.82            1.72           5.54          27.7             463.9              0.00           463.9          NaN        NaN                 NaN
# 4378         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin    90-95              3.54            0.82           4.36          21.8             485.7              0.00           485.7          NaN        NaN                 NaN
# 4379         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin   95-100              3.13            0.28           3.42          17.1             502.8              0.00           502.8          NaN        NaN                 NaN
# 4380         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin  100-105              2.69            0.32           3.01          15.1             517.8              0.00           517.8          NaN        NaN                 NaN
# 4381         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin  105-110              2.40           -0.60           1.80           9.0             526.8              0.00           526.8          NaN        NaN                 NaN
# 4382         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin  110-115              2.09           -0.19           1.91           9.5             536.4              0.00           536.4          NaN        NaN                 NaN
# 4383         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin  115-120              1.59           -0.45           1.14           5.7             542.1              0.00           542.1          NaN        NaN                 NaN
# 4384         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin  120-125              1.30           -0.43           0.87           4.3             546.4              0.00           546.4          NaN        NaN                 NaN
# 4385         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin  125-130              1.20           -0.35           0.86           4.3             550.7              0.00           550.7          NaN        NaN                 NaN
# 4386         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin  130-135              1.10           -0.29           0.82           4.1             554.8              0.00           554.8          NaN        NaN                 NaN
# 4387         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin  135-140              0.95           -0.02           0.93           4.6             559.4              0.00           559.4          NaN        NaN                 NaN
# 4388         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin  140-145              0.81           -0.22           0.59           3.0             562.4              0.00           562.4          NaN        NaN                 NaN
# 4389         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin  145-150              0.69           -0.20           0.49           2.5             564.8              0.00           564.8          NaN        NaN                 NaN
# 4390         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin  150-155              0.60           -0.18           0.42           2.1             566.9              0.00           566.9          NaN        NaN                 NaN
# 4391         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin  155-160              0.49           -0.04           0.45           2.3             569.2              0.00           569.2          NaN        NaN                 NaN
# 4392         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin  160-165              0.43           -0.12           0.31           1.6             570.7              0.00           570.7          NaN        NaN                 NaN
# 4393         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin  165-170              0.38           -0.10           0.28           1.4             572.1              0.00           572.1          NaN        NaN                 NaN
# 4394         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin  170-175              0.30           -0.09           0.21           1.0             573.2              0.00           573.2          NaN        NaN                 NaN
# 4395         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin  175-180              0.28            0.28           0.56           2.8             576.0              0.00           576.0          NaN        NaN                 NaN
# 4396         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin  180-185              0.23           -0.14           0.09           0.5             576.4              0.00           576.4          NaN        NaN                 NaN
# 4397         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin  185-190              0.23           -0.05           0.18           0.9             577.3              0.00           577.3          NaN        NaN                 NaN
# 4398         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin  190-195              0.08           -0.14          -0.07          -0.3             577.0              0.00           577.0          NaN        NaN                 NaN
# 4399         NPI     NPI         Nat Regen - Scots Pine         Nat Regen - Scots Pine          NaN   4.0      2.0    NO_thin  195-200              0.06           -0.11          -0.05          -0.3             576.7              0.00           576.7          NaN        NaN                 NaN

# %% [markdown]
# The `WCCEstablishment` data frame contains the establishment emission values calculated using the same methodology as in the "StandardProjectCarbonCalculator" sheet of the excel tool.
# Column definitions:
# * seedlingSpacing
# * variable - the establishment emission source, one of:
#     * seedling
#     * groundPrepFuel
#     * treeShelters
#     * fencing
#     * herbicide
#     * totalEmissions
# * totalEmissions- the carbon emissions associated with that seedlingSpacing and variable. Units of tCO2e.

# %%
baseline_WCCEstablishment = ESCresponse_dict.get("Baseline").get("WCCEstablishment")
baseline_WCCEstablishment.head()
# Out:
#    seedlingSpacing  variable  totalEmissions
# 0              1.2  seedling          -12.60
# 1              1.4  seedling           -9.24
# 2              1.5  seedling           -8.04
# 3              1.7  seedling           -6.24
# 4              2.0  seedling           -4.56

# %% [markdown]
# The `WCCSoilLoss` data frame contains data on the soil carbon emissions during the year of establishment (Year 1) for each country, percentage topsoil carbon to be subtracted and previous land use.
# Column definitions:
# * Country - The country in which the site is located.
# * topsoilCarbonSubtract - the percentage of topsoil carbon to subtract .
# * Seminatural - the soil carbon emissions associated with the previous land-use "Semi-natural", units in tCO2e/ha.
# * Pasture - the soil carbon emissions associated with the previous land-use "Pasture, units in tCO2e/ha.
# * Arable - the soil carbon emissions associated with the previous land-use "Arable", units in tCO2e/ha.

# %%
baseline_WCCSoilLoss = ESCresponse_dict.get("Baseline").get("WCCSoilLoss")
baseline_WCCSoilLoss.head()
# Out:
#             Country  topsoilCarbonSubtract  Seminatural   Pasture    Arable
# 0           England                      0          0.0  0.000000  0.000000
# 1          Scotland                      0          0.0  0.000000  0.000000
# 2             Wales                      0          0.0  0.000000  0.000000
# 3  Northern Ireland                      0          0.0  0.000000  0.000000
# 4           England                      2         -8.8 -5.866667 -5.133333

# %% [markdown]
# The `WCCSoilSeq` data frame contains data on the cumulative soil carbon sequestration for mineral soils which where the former land use was arable agriculture.
# Column definitions:
# * period - The period of years associated with the wcc data. Retrieved from column Y in the "StandardProjectCarbonCalculator" sheet of the excel tool.
# * cumSoilSeq - Calculated by multiplying column AY in the "StandardProjectCarbonCalculator" by the site area. Units in tCO2e.

# %%
baseline_WCCSoilSeq = ESCresponse_dict.get("Baseline").get("WCCSoilSeq")
baseline_WCCSoilSeq.head()
# Out:
#    period  cumSoilSeq
# 0     0-5         5.5
# 1    5-10        11.0
# 2   10-15        16.5
# 3   15-20        22.0
# 4   20-25        27.5

# %% [markdown]
# ## Calculate Claimable Carbon Sequestration

# %% [markdown]
# To calculate the average total claimable sequestration by year in tCO2e/ha perform the following calculations using the API outputs.
#
# Columns suffixed with (<[A-Z]>) correspond to the columns CB to CM of Version 2.4 (March 2021) of the WCC excel tool.

# %% [markdown]
# First, retrieve the WCC Biomass Carbon Lookup Table (BCLT) and Clearfell Max Seq Values (CMSV) values for selected species, e.g. Rowan.

# %%
baseline_WCCTreeValues_ROW = baseline_WCCTreeValues[baseline_WCCTreeValues["speciesCode"] == "ROW"]
baseline_WCCTreeValues_ROW.head()
# Out:
#      speciesCode wccCode speciesScientific speciesName  estimatedYC   YC  \
# 1440         ROW     SAB  Sorbus aucuparia       Rowan          2.4  2.0
# 1441         ROW     SAB  Sorbus aucuparia       Rowan          2.4  2.0
# 1442         ROW     SAB  Sorbus aucuparia       Rowan          2.4  2.0
# 1443         ROW     SAB  Sorbus aucuparia       Rowan          2.4  2.0
# 1444         ROW     SAB  Sorbus aucuparia       Rowan          2.4  2.0
#
#       spacing management  period  standingCarbonYr  debrisCarbonYr  \
# 1440      1.5    NO_thin     0-5               NaN             NaN
# 1441      1.5    NO_thin    5-10               NaN             NaN
# 1442      1.5    NO_thin   10-15               NaN             NaN
# 1443      1.5    NO_thin   15-20               NaN             NaN
# 1444      1.5    NO_thin   20-25               NaN             NaN
#
#       totalCarbonYr  cumCarbon5Yr  cumBiomassCarbon  cumEmissionsMgmt  \
# 1440            NaN           NaN               NaN               NaN
# 1441            NaN           NaN               NaN               NaN
# 1442            NaN           NaN               NaN               NaN
# 1443            NaN           NaN               NaN               NaN
# 1444            NaN           NaN               NaN               NaN
#
#       cumTotalCarbon  remCarbonYr  periodEnd  clearfellCapCarbon
# 1440             2.7          NaN        NaN                 NaN
# 1441             9.6          NaN        NaN                 NaN
# 1442            28.9          NaN        NaN                 NaN
# 1443            76.4          NaN        NaN                 NaN
# 1444           120.6          NaN        NaN                 NaN

# %% [markdown]
# Select the BCLT and CMSV values for a particular spacing and management regime, e.g. 1.5m and Thinned.

# %%
baseline_WCCTreeValues_ROW_1p5_Thinned = baseline_WCCTreeValues_ROW[(baseline_WCCTreeValues_ROW.spacing == 1.5) & (baseline_WCCTreeValues_ROW.management == "Thinned")]
baseline_WCCTreeValues_ROW_1p5_Thinned.head()
# Out:
#      speciesCode wccCode speciesScientific speciesName  estimatedYC   YC  \
# 1480         ROW     SAB  Sorbus aucuparia       Rowan          2.4  2.0
# 1481         ROW     SAB  Sorbus aucuparia       Rowan          2.4  2.0
# 1482         ROW     SAB  Sorbus aucuparia       Rowan          2.4  2.0
# 1483         ROW     SAB  Sorbus aucuparia       Rowan          2.4  2.0
# 1484         ROW     SAB  Sorbus aucuparia       Rowan          2.4  2.0
#
#       spacing management  period  standingCarbonYr  debrisCarbonYr  \
# 1480      1.5    Thinned     0-5               NaN             NaN
# 1481      1.5    Thinned    5-10               NaN             NaN
# 1482      1.5    Thinned   10-15               NaN             NaN
# 1483      1.5    Thinned   15-20               NaN             NaN
# 1484      1.5    Thinned   20-25               NaN             NaN
#
#       totalCarbonYr  cumCarbon5Yr  cumBiomassCarbon  cumEmissionsMgmt  \
# 1480            NaN           NaN               NaN               NaN
# 1481            NaN           NaN               NaN               NaN
# 1482            NaN           NaN               NaN               NaN
# 1483            NaN           NaN               NaN               NaN
# 1484            NaN           NaN               NaN               NaN
#
#       cumTotalCarbon  remCarbonYr  periodEnd  clearfellCapCarbon
# 1480             2.7          NaN        NaN                 NaN
# 1481             9.6          NaN        NaN                 NaN
# 1482            28.9          NaN        NaN                 NaN
# 1483            70.6          NaN        NaN                 NaN
# 1484            91.1          NaN        NaN                 NaN

# %% [markdown]
# Define a species composition for the site and join to a trimmed WCCTreeValues dataframe.

# %%
species_composition = pandas.DataFrame.from_dict(data = {"speciesCode": "ROW", "proportion": [1]})
species_composition
# Out:
#   speciesCode  proportion
# 0         ROW           1

# %%
df = baseline_WCCTreeValues_ROW_1p5_Thinned

df = df[["speciesCode", "period", "cumTotalCarbon"]]
df = df.merge(species_composition, on = ["speciesCode"])
df.head()
# Out:
#   speciesCode  period  cumTotalCarbon  proportion
# 0         ROW     0-5             2.7           1
# 1         ROW    5-10             9.6           1
# 2         ROW   10-15            28.9           1
# 3         ROW   15-20            70.6           1
# 4         ROW   20-25            91.1           1

# %% [markdown]
# Multiply the 'Cumulative total sequestration" data (cumTotalCarbon) by the species proportion and estimated area.

# %%
df["cumTotalCarbonSite (A)"] = df["cumTotalCarbon"] * df["proportion"] * wccEstArea
df.head()
# Out:
#   speciesCode  period  cumTotalCarbon  proportion  cumTotalCarbonSite (A)
# 0         ROW     0-5             2.7           1                    32.4
# 1         ROW    5-10             9.6           1                   115.2
# 2         ROW   10-15            28.9           1                   346.8
# 3         ROW   15-20            70.6           1                   847.2
# 4         ROW   20-25            91.1           1                  1093.2

# %% [markdown]
# Sum across all species

# %%
df = df.drop(columns = ["speciesCode", "cumTotalCarbon", "proportion"])
df = df.set_index("period")
df.sum(axis = 0).to_frame()
df = df.reset_index()
df.head()
# Out:
#    period  cumTotalCarbonSite (A)
# 0     0-5                    32.4
# 1    5-10                   115.2
# 2   10-15                   346.8
# 3   15-20                   847.2
# 4   20-25                  1093.2

# %% [markdown]
# Add a 20% buffer by multiplying the Cumulative total sequestration for the site by 0.8

# %%
df["cumTotalCarbonSiteReduced (B)"] = df["cumTotalCarbonSite (A)"] * 0.8
df.head()
# Out:
#    period  cumTotalCarbonSite (A)  cumTotalCarbonSiteReduced (B)
# 0     0-5                    32.4                          25.92
# 1    5-10                   115.2                          92.16
# 2   10-15                   346.8                         277.44
# 3   15-20                   847.2                         677.76
# 4   20-25                  1093.2                         874.56

# %% [markdown]
# Retrieve the total establishment emissions for the selected spacing and add to the dataframe.

# %%
totalEstablishmentC = baseline_WCCEstablishment[(baseline_WCCEstablishment.seedlingSpacing == 1.5) & (baseline_WCCEstablishment.variable == "total")]
totalEstablishmentC = totalEstablishmentC.drop(columns = ["seedlingSpacing", "variable"]).reset_index(drop = True)
totalEstablishmentC = totalEstablishmentC.rename(columns = {"totalEmissions": "establishmentCarbonLoss (C)"})
df["establishmentCarbonLoss (C)"] = totalEstablishmentC._get_value(0, 0, takeable = True)
df.head()
# Out:
#    period  cumTotalCarbonSite (A)  cumTotalCarbonSiteReduced (B)  \
# 0     0-5                    32.4                          25.92
# 1    5-10                   115.2                          92.16
# 2   10-15                   346.8                         277.44
# 3   15-20                   847.2                         677.76
# 4   20-25                  1093.2                         874.56
#
#    establishmentCarbonLoss (C)
# 0                      -81.412
# 1                      -81.412
# 2                      -81.412
# 3                      -81.412
# 4                      -81.412

# %% [markdown]
# Calculate soil carbon flux by summing soil loss and soil sequestration data .
# To do this first identify the % topsoil carbon (0-30cm) loss associated with the method of site preparation and soil type.

# %%
establishmentMethods = pandas.DataFrame.from_dict(data = {"MethodSitePrep": ["Negligible Disturbance", "Low Disturbance", "Medium Disturbance", "High Disturbance", "Very High Disturbance"],
                                                          "Organomineral": [0, 5, 10, 20, 40],
                                                          "Mineral": [0, 0, 2, 5, 10]})

establishmentMethods = establishmentMethods.set_index("MethodSitePrep")
percSoilLoss = establishmentMethods._get_value("Medium Disturbance", "Mineral")
percSoilLoss
# Out:
# 2

# %% [markdown]
# Retrieve the soil carbon lost for the selected country, previous land use, and % topsoil carbon (0-30cm) loss identified above.

# %%
soilCLoss = baseline_WCCSoilLoss[baseline_WCCSoilLoss["topsoilCarbonSubtract"] == percSoilLoss]
soilCLoss = soilCLoss.set_index("Country")
soilCLoss = soilCLoss._get_value("England", "Arable")
soilCLoss
# Out:
# -5.133333333

# %%
soilCFlux = baseline_WCCSoilSeq
soilCFlux["cumSoilLoss"] = soilCLoss
soilCFlux["cumSoilCarbonFlux (D)"] = soilCFlux["cumSoilLoss"] + soilCFlux["cumSoilSeq"]
soilCFlux = soilCFlux.drop(columns = ["cumSoilSeq", "cumSoilLoss"])
soilCFlux.head()
# Out:
#    period  cumSoilCarbonFlux (D)
# 0     0-5               0.366667
# 1    5-10               5.866667
# 2   10-15              11.366667
# 3   15-20              16.866667
# 4   20-25              22.366667

# %%
df = df.merge(soilCFlux, on = ["period"])
df.head()
# Out:
#    period  cumTotalCarbonSite (A)  cumTotalCarbonSiteReduced (B)  \
# 0     0-5                    32.4                          25.92
# 1    5-10                   115.2                          92.16
# 2   10-15                   346.8                         277.44
# 3   15-20                   847.2                         677.76
# 4   20-25                  1093.2                         874.56
#
#    establishmentCarbonLoss (C)  cumSoilCarbonFlux (D)
# 0                      -81.412               0.366667
# 1                      -81.412               5.866667
# 2                      -81.412              11.366667
# 3                      -81.412              16.866667
# 4                      -81.412              22.366667

# %% [markdown]
# Calculate the total cumulative carbon sequestration

# %%
df["totalProjectCarbonSeq (E)"] = df["cumTotalCarbonSiteReduced (B)"] + df["establishmentCarbonLoss (C)"] + df["cumSoilCarbonFlux (D)"]
df.head()
# Out:
#    period  cumTotalCarbonSite (A)  cumTotalCarbonSiteReduced (B)  \
# 0     0-5                    32.4                          25.92
# 1    5-10                   115.2                          92.16
# 2   10-15                   346.8                         277.44
# 3   15-20                   847.2                         677.76
# 4   20-25                  1093.2                         874.56
#
#    establishmentCarbonLoss (C)  cumSoilCarbonFlux (D)  \
# 0                      -81.412               0.366667
# 1                      -81.412               5.866667
# 2                      -81.412              11.366667
# 3                      -81.412              16.866667
# 4                      -81.412              22.366667
#
#    totalProjectCarbonSeq (E)
# 0                 -55.125333
# 1                  16.614667
# 2                 207.394667
# 3                 613.214667
# 4                 815.514667

# %% [markdown]
# Optionally, add Baseline and Leakage data then calculate the adjusted, net total project carbon sequestration

# %%
df["Baseline (F)"] = 0
df["Leakage (G)"] = 0
df["netTotalProjectCarbonSeq (H)"] = df["totalProjectCarbonSeq (E)"]+ df["Baseline (F)"] + df["Leakage (G)"]
df.head()
# Out:
#    period  cumTotalCarbonSite (A)  cumTotalCarbonSiteReduced (B)  \
# 0     0-5                    32.4                          25.92
# 1    5-10                   115.2                          92.16
# 2   10-15                   346.8                         277.44
# 3   15-20                   847.2                         677.76
# 4   20-25                  1093.2                         874.56
#
#    establishmentCarbonLoss (C)  cumSoilCarbonFlux (D)  \
# 0                      -81.412               0.366667
# 1                      -81.412               5.866667
# 2                      -81.412              11.366667
# 3                      -81.412              16.866667
# 4                      -81.412              22.366667
#
#    totalProjectCarbonSeq (E)  Baseline (F)  Leakage (G)  \
# 0                 -55.125333             0            0
# 1                  16.614667             0            0
# 2                 207.394667             0            0
# 3                 613.214667             0            0
# 4                 815.514667             0            0
#
#    netTotalProjectCarbonSeq (H)
# 0                    -55.125333
# 1                     16.614667
# 2                    207.394667
# 3                    613.214667
# 4                    815.514667

# %% [markdown]
# Calculate the claimable carbon sequestration by adding a final 20% buffer

# %%
df["claimableCarbonSeq (J)"] = df["netTotalProjectCarbonSeq (H)"] * 0.8
df.head()
# Out:
#    period  cumTotalCarbonSite (A)  cumTotalCarbonSiteReduced (B)  \
# 0     0-5                    32.4                          25.92
# 1    5-10                   115.2                          92.16
# 2   10-15                   346.8                         277.44
# 3   15-20                   847.2                         677.76
# 4   20-25                  1093.2                         874.56
#
#    establishmentCarbonLoss (C)  cumSoilCarbonFlux (D)  \
# 0                      -81.412               0.366667
# 1                      -81.412               5.866667
# 2                      -81.412              11.366667
# 3                      -81.412              16.866667
# 4                      -81.412              22.366667
#
#    totalProjectCarbonSeq (E)  Baseline (F)  Leakage (G)  \
# 0                 -55.125333             0            0
# 1                  16.614667             0            0
# 2                 207.394667             0            0
# 3                 613.214667             0            0
# 4                 815.514667             0            0
#
#    netTotalProjectCarbonSeq (H)  claimableCarbonSeq (J)
# 0                    -55.125333              -44.100267
# 1                     16.614667               13.291733
# 2                    207.394667              165.915733
# 3                    613.214667              490.571733
# 4                    815.514667              652.411733

# %% [markdown]
# Calculate the mean claimable carbon sequestration per hectare, in tCO2e per ha per year

# %%
df["meanClaimableCarbonSeqPerHa (K)"] = df["claimableCarbonSeq (J)"] / wccEstArea
df.head()
# Out:
#    period  cumTotalCarbonSite (A)  cumTotalCarbonSiteReduced (B)  \
# 0     0-5                    32.4                          25.92
# 1    5-10                   115.2                          92.16
# 2   10-15                   346.8                         277.44
# 3   15-20                   847.2                         677.76
# 4   20-25                  1093.2                         874.56
#
#    establishmentCarbonLoss (C)  cumSoilCarbonFlux (D)  \
# 0                      -81.412               0.366667
# 1                      -81.412               5.866667
# 2                      -81.412              11.366667
# 3                      -81.412              16.866667
# 4                      -81.412              22.366667
#
#    totalProjectCarbonSeq (E)  Baseline (F)  Leakage (G)  \
# 0                 -55.125333             0            0
# 1                  16.614667             0            0
# 2                 207.394667             0            0
# 3                 613.214667             0            0
# 4                 815.514667             0            0
#
#    netTotalProjectCarbonSeq (H)  claimableCarbonSeq (J)  \
# 0                    -55.125333              -44.100267
# 1                     16.614667               13.291733
# 2                    207.394667              165.915733
# 3                    613.214667              490.571733
# 4                    815.514667              652.411733
#
#    meanClaimableCarbonSeqPerHa (K)
# 0                        -3.675022
# 1                         1.107644
# 2                        13.826311
# 3                        40.880978
# 4                        54.367644
